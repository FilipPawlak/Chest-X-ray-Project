# %% [markdown]
# # Chest X-ray Project

# %% [markdown]
# ### Importing needed libraries

# %%
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"  # - only if using AMD card

import keras
import keras.applications as kapp
from keras.applications import *

from keras.preprocessing import image
from keras.models import Model
import numpy as np
import io

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout

from keras.preprocessing import image
from keras.models import Model


from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import time
from sklearn.metrics import accuracy_score
import pandas as pd

import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using plaidml.keras.backend backend.

# %% [markdown]
# ### Images preparation

# %%
train_data_dir = r'C:\Users\Filip\Desktop\Python\Projekt_kodołamacz\chest_xray\chest_xray\train'
test_data_dir = r'C:\Users\Filip\Desktop\Python\Projekt_kodołamacz\chest_xray\chest_xray\test'


img_width, img_height = 200, 200
batch_size = 1


nb_train_samples = 1000 # adjustable, possible to increase depending on computing power
nb_validation_samples = 624


train_datagen = ImageDataGenerator(rescale=1./255, 
                                   shear_range=0.2, 
                                   zoom_range=0.2,
                                   brightness_range= [0.5,1.5],
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255) # test images without augmentation, only rescaling

train_generator = train_datagen.flow_from_directory(train_data_dir, 
                                                    target_size=(img_height, img_width), 
                                                    batch_size=batch_size, class_mode='binary')

validation_generator = test_datagen.flow_from_directory(test_data_dir,target_size=(img_height, img_width), 
                                                        batch_size=batch_size,class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# ### Example of image

# %%
plt.imshow(train_generator[0][0][0])
print(train_generator[0][1][0]) #if 1 then pneumonia
# Out:
# 1.0

# %%
plt.imshow(train_generator[0][0][1])
print(train_generator[0][1][1]) #if 1 then pneumonia
# Out:
# 1.0

# %%
plt.imshow(train_generator[0][0][2])
print(train_generator[0][1][2]) #if 1 then pneumonia
# Out:
# 1.0

# %% [markdown]
# ### Model evaluation preparation

# %%
def evaluate_model(model, generator):
    score = model.evaluate_generator(generator=generator,              
                                     verbose=0)
    return(score[0], score[1])

# %%
# Preparing dashboard
wyniki = pd.DataFrame(columns = ['val_loss','val_acc'])

# %% [markdown]
# ### Training models

# %%
h,w = 200, 200 # hight and width of input data for model

# %% [markdown]
# ### VGG19

# %%
# Model CNN - VGG19
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(h,w,3))

# Top layers
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(128, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# Combinig base model with additional CNN layers
new_model = Sequential()
new_model.add(base_model)
new_model.add(top_model)
new_model.layers[0].trainable = False

# Model compilation
new_model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# Callbacks
my_callbacks = [
    EarlyStopping(patience=4, monitor='val_loss', min_delta=0.05, restore_best_weights=True),
    ModelCheckpoint(filepath='model1.h5')
]

# CNN training
new_model.fit_generator(train_generator, steps_per_epoch=nb_train_samples, epochs=80, callbacks=my_callbacks, validation_data=validation_generator, validation_steps=nb_validation_samples)
# Out:
# INFO:plaidml:Opening device "opencl_amd_pitcairn.0"
# Epoch 1/80
# 1000/1000 [==============================] - 1809s 2s/step - loss: 0.3041 - acc: 0.8695 - val_loss: 0.2916 - val_acc: 0.9087
# Epoch 2/80
# 1000/1000 [==============================] - 1645s 2s/step - loss: 0.2203 - acc: 0.9012 - val_loss: 0.3510 - val_acc: 0.8830
# Epoch 3/80
# 1000/1000 [==============================] - 1644s 2s/step - loss: 0.2132 - acc: 0.9074 - val_loss: 0.2676 - val_acc: 0.8974
# Epoch 4/80
# 1000/1000 [==============================] - 1644s 2s/step - loss: 0.2061 - acc: 0.9021 - val_loss: 0.2492 - val_acc: 0.9199
# Epoch 5/80
# 1000/1000 [==============================] - 1645s 2s/step - loss: 0.1991 - acc: 0.9143 - val_loss: 0.2547 - val_acc: 0.9135

# %%
# Adding results to dashboard
wyniki.loc['VGG19'] = evaluate_model(new_model, validation_generator)

# %% [markdown]
# ### VGG16

# %%
# Model CNN - VGG16
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(h,w,3)) 

# Top layers
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(128, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# Combinig base model with additional CNN layers
new_model = Sequential()
new_model.add(base_model)
new_model.add(top_model)
new_model.layers[0].trainable = False

# Model compilation
new_model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# Callbacks
my_callbacks = [
    EarlyStopping(patience=4, monitor='val_loss', min_delta=0.05, restore_best_weights=True),
    ModelCheckpoint(filepath='model1.h5')
]


# CNN training
new_model.fit_generator(train_generator, 
                        steps_per_epoch=nb_train_samples, 
                        epochs=80, 
                        callbacks=my_callbacks, 
                        validation_data=validation_generator, 
                        validation_steps=nb_validation_samples)
# Out:
# Epoch 1/80
# 1000/1000 [==============================] - 1325s 1s/step - loss: 0.2265 - acc: 0.9146 - val_loss: 0.2114 - val_acc: 0.9279
# Epoch 2/80
# 1000/1000 [==============================] - 1315s 1s/step - loss: 0.1628 - acc: 0.9386 - val_loss: 0.1958 - val_acc: 0.9279
# Epoch 3/80
# 1000/1000 [==============================] - 1315s 1s/step - loss: 0.1581 - acc: 0.9377 - val_loss: 0.2398 - val_acc: 0.9247
# Epoch 4/80
# 1000/1000 [==============================] - 1314s 1s/step - loss: 0.1468 - acc: 0.9463 - val_loss: 0.2366 - val_acc: 0.9279
# Epoch 5/80
# 1000/1000 [==============================] - 1314s 1s/step - loss: 0.1378 - acc: 0.9478 - val_loss: 0.1959 - val_acc: 0.9327

# %%
# Adding results to dashboard
wyniki.loc['VGG16'] = evaluate_model(new_model, validation_generator)

# %% [markdown]
# ### InceptionV3

# %%
# Model CNN - InceptionV3

base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(h,w,3)) 

# Top layers
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(128, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# Combinig base model with additional CNN layers
new_model = Sequential()
new_model.add(base_model)
new_model.add(top_model)
new_model.layers[0].trainable = False

# Model compilation
new_model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# Callbacks
my_callbacks = [
    EarlyStopping(patience=4, monitor='val_loss', min_delta=0.05, restore_best_weights=True),
    ModelCheckpoint(filepath='model1.h5')
]

# CNN training
new_model.fit_generator(train_generator, 
                        steps_per_epoch=nb_train_samples, 
                        epochs=80, 
                        callbacks=my_callbacks, 
                        validation_data=validation_generator, 
                        validation_steps=nb_validation_samples)
# Out:
# Epoch 1/80
# INFO:plaidml:Analyzing Ops: 804 of 2063 operations complete
#  999/1000 [============================>.] - ETA: 0s - loss: 4.1013 - acc: 0.7421
# INFO:plaidml:Analyzing Ops: 800 of 1112 operations complete
# 1000/1000 [==============================] - 592s 592ms/step - loss: 4.1032 - acc: 0.7419 - val_loss: 5.9784 - val_acc: 0.6250
# Epoch 2/80
# 1000/1000 [==============================] - 525s 525ms/step - loss: 4.0872 - acc: 0.7436 - val_loss: 5.9784 - val_acc: 0.6250
# Epoch 3/80
# 1000/1000 [==============================] - 517s 517ms/step - loss: 4.0793 - acc: 0.7441 - val_loss: 5.9784 - val_acc: 0.6250
# Epoch 4/80
# 1000/1000 [==============================] - 518s 518ms/step - loss: 4.1121 - acc: 0.7421 - val_loss: 5.9784 - val_acc: 0.6250
# Epoch 5/80
# 1000/1000 [==============================] - 517s 517ms/step - loss: 4.1091 - acc: 0.7422 - val_loss: 5.9784 - val_acc: 0.6250

# %%
# Adding results to dashboard
wyniki.loc['InceptionV3'] = evaluate_model(new_model, validation_generator)

# %% [markdown]
# ### Xception

# %%
# Model CNN - Xception

base_model = Xception(weights='imagenet', include_top=False, input_shape=(h,w,3)) 

# Top layers
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(128, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# Combinig base model with additional CNN layers
new_model = Sequential()
new_model.add(base_model)
new_model.add(top_model)
new_model.layers[0].trainable = False

# Model compilation
new_model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# Callbacks
my_callbacks = [
    EarlyStopping(patience=4, monitor='val_loss', min_delta=0.05, restore_best_weights=True),
    ModelCheckpoint(filepath='model_ResNet50.h5')
]



# CNN training
new_model.fit_generator(train_generator, 
                        steps_per_epoch=nb_train_samples, 
                        epochs=80, 
                        callbacks=my_callbacks, 
                        validation_data=validation_generator, 
                        validation_steps=nb_validation_samples)

# %%
# Adding results to dashboard
wyniki.loc['Xception'] = evaluate_model(new_model, validation_generator)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\library.py in _logger_callback(self, unused_arg, level, msg)
#     131         raise self.last_status()
#     132
# --> 133     def _logger_callback(self, unused_arg, level, msg):
#     134         severity = _LOG_SEVERITY_MAP.get(level, logging.ERROR)
#     135         self._logger(severity, msg.decode())
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# Unknown                                   Traceback (most recent call last)
# <ipython-input-22-652f87c1faab> in <module>
#       1 # Adding results to dashboard
# ----> 2 wyniki.loc['Xception'] = evaluate_model(new_model, validation_generator)
#
# <ipython-input-6-22617e32bf95> in evaluate_model(model, generator)
#       1 def evaluate_model(model, generator):
# ----> 2     score = model.evaluate_generator(generator=generator,
#       3                                      verbose=0)
#       4     return(score[0], score[1])
#
# ~\.conda\envs\ML\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\.conda\envs\ML\lib\site-packages\keras\engine\training.py in evaluate_generator(self, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#    1464                 data in an invalid format.
#    1465         """
# -> 1466         return training_generator.evaluate_generator(
#    1467             self, generator,
#    1468             steps=steps,
#
# ~\.conda\envs\ML\lib\site-packages\keras\engine\training_generator.py in evaluate_generator(model, generator, steps, max_queue_size, workers, use_multiprocessing, verbose)
#     344                                  'or (x, y). Found: ' +
#     345                                  str(generator_output))
# --> 346             outs = model.test_on_batch(x, y, sample_weight=sample_weight)
#     347             outs = to_list(outs)
#     348             outs_per_batch.append(outs)
#
# ~\.conda\envs\ML\lib\site-packages\keras\engine\training.py in test_on_batch(self, x, y, sample_weight)
#    1254             ins = x + y + sample_weights
#    1255         self._make_test_function()
# -> 1256         outputs = self.test_function(ins)
#    1257         return unpack_singleton(outputs)
#    1258
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\keras\backend.py in __call__(self, inputs)
#     187             self._invoker.set_output(name, t)
#     188
# --> 189         self._invoker.invoke()
#     190
#     191         return [t.as_ndarray(_ctx) for t in tensors]
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\__init__.py in invoke(self)
#    1473
#    1474     def invoke(self):
# -> 1475         return Invocation(self._ctx, self)
#    1476
#    1477     def save(self, filename):
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\__init__.py in __init__(self, ctx, invoker)
#    1482
#    1483     def __init__(self, ctx, invoker):
# -> 1484         self._as_parameter_ = _lib().plaidml_schedule_invocation(ctx, invoker)
#    1485         self._free = _lib().plaidml_free_invocation
#    1486
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\__init__.py in _check_err(self, result, func, args)
#     775         if func == self.plaidml_map_buffer_current and args[2]:
#     776             return None
# --> 777         self.raise_last_status()
#     778
#     779
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\library.py in raise_last_status(self)
#     129
#     130     def raise_last_status(self):
# --> 131         raise self.last_status()
#     132
#     133     def _logger_callback(self, unused_arg, level, msg):
#
# Unknown: Unable to allocate device-local memory: CL_MEM_OBJECT_ALLOCATION_FAILURE

# %%
from keras import backend as K
K.clear_session()

# %% [markdown]
# ### ResNet50

# %%
# Model CNN - ResNet50

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(h,w,3)) 

# Top layers
top_model = Sequential()
top_model.add(Flatten(input_shape=base_model.output_shape[1:]))
top_model.add(Dense(128, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(1, activation='sigmoid'))

# Combinig base model with additional CNN layers
new_model = Sequential()
new_model.add(base_model)
new_model.add(top_model)
new_model.layers[0].trainable = False

# Model compilation
new_model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# Callbacks
my_callbacks = [
    EarlyStopping(patience=4, monitor='val_loss', min_delta=0.05, restore_best_weights=True),
    ModelCheckpoint(filepath='model1.h5')
]



# CNN training
new_model.fit_generator(train_generator, 
                        steps_per_epoch=nb_train_samples, 
                        epochs=80, 
                        callbacks=my_callbacks, 
                        validation_data=validation_generator, 
                        validation_steps=nb_validation_samples)
# Out:
# ERROR:plaidml:Unable to allocate device-local memory: CL_MEM_OBJECT_ALLOCATION_FAILURE
# ---------------------------------------------------------------------------
# Unknown                                   Traceback (most recent call last)
# <ipython-input-21-dda54c060884> in <module>
#       1 # Model CNN - ResNet50
#       2
# ----> 3 base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(h,w,3))
#       4
#       5 # Top layers
#
# ~\.conda\envs\ML\lib\site-packages\keras\applications\__init__.py in wrapper(*args, **kwargs)
#      26             kwargs['models'] = models
#      27             kwargs['utils'] = utils
# ---> 28         return base_fun(*args, **kwargs)
#      29
#      30     return wrapper
#
# ~\.conda\envs\ML\lib\site-packages\keras\applications\resnet50.py in ResNet50(*args, **kwargs)
#       9 @keras_modules_injection
#      10 def ResNet50(*args, **kwargs):
# ---> 11     return resnet50.ResNet50(*args, **kwargs)
#      12
#      13
#
# ~\.conda\envs\ML\lib\site-packages\keras_applications\resnet50.py in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes, **kwargs)
#     250     x = identity_block(x, 3, [256, 256, 1024], stage=4, block='f')
#     251
# --> 252     x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
#     253     x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
#     254     x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')
#
# ~\.conda\envs\ML\lib\site-packages\keras_applications\resnet50.py in conv_block(input_tensor, kernel_size, filters, stage, block, strides)
#     129     x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)
#     130
# --> 131     shortcut = layers.Conv2D(filters3, (1, 1), strides=strides,
#     132                              kernel_initializer='he_normal',
#     133                              name=conv_name_base + '1')(input_tensor)
#
# ~\.conda\envs\ML\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     429                                          'You can build it manually via: '
#     430                                          '`layer.build(batch_input_shape)`')
# --> 431                 self.build(unpack_singleton(input_shapes))
#     432                 self.built = True
#     433
#
# ~\.conda\envs\ML\lib\site-packages\keras\layers\convolutional.py in build(self, input_shape)
#     135         kernel_shape = self.kernel_size + (input_dim, self.filters)
#     136
# --> 137         self.kernel = self.add_weight(shape=kernel_shape,
#     138                                       initializer=self.kernel_initializer,
#     139                                       name='kernel',
#
# ~\.conda\envs\ML\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\.conda\envs\ML\lib\site-packages\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint)
#     247         if dtype is None:
#     248             dtype = K.floatx()
# --> 249         weight = K.variable(initializer(shape),
#     250                             dtype=dtype,
#     251                             name=name,
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\keras\backend.py in wrapper(*args, **kwargs)
#      57     def wrapper(*args, **kwargs):
#      58         # Call the requested function regardless
# ---> 59         return func(*args, **kwargs)
#      60
#      61     return wrapper
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\keras\backend.py in variable(value, dtype, name, constraint)
#    1925         tensor = plaidml.Tensor(_device(), shape)
#    1926         invoker.set_output('out', tensor)
# -> 1927         invoker.invoke()
#    1928         return ptile.Value.from_var(tensor, [d.size for d in shape.dimensions], shape.dtype,
#    1929                                     _prepend_name_scope(name, 'variable'))
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\__init__.py in invoke(self)
#    1473
#    1474     def invoke(self):
# -> 1475         return Invocation(self._ctx, self)
#    1476
#    1477     def save(self, filename):
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\__init__.py in __init__(self, ctx, invoker)
#    1482
#    1483     def __init__(self, ctx, invoker):
# -> 1484         self._as_parameter_ = _lib().plaidml_schedule_invocation(ctx, invoker)
#    1485         self._free = _lib().plaidml_free_invocation
#    1486
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\__init__.py in _check_err(self, result, func, args)
#     775         if func == self.plaidml_map_buffer_current and args[2]:
#     776             return None
# --> 777         self.raise_last_status()
#     778
#     779
#
# ~\.conda\envs\ML\lib\site-packages\plaidml\library.py in raise_last_status(self)
#     129
#     130     def raise_last_status(self):
# --> 131         raise self.last_status()
#     132
#     133     def _logger_callback(self, unused_arg, level, msg):
#
# Unknown: Unable to allocate device-local memory: CL_MEM_OBJECT_ALLOCATION_FAILURE

# %%
# Adding results to dashboard
wyniki.loc['ResNet50'] = evaluate_model(new_model, validation_generator)

# %% [markdown]
# ### Comparision between models

# %%
print(wyniki)
